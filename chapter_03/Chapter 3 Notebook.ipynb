# %% [markdown]
# Chapter 3 - Engaging GPT Assistants

# %%
# Here I used a gpt to extract paystub data from pdf files
# I had issues downloading it but I was able to get it as pieces of
# a python dictionary

import polars as pl

data = [
    {
        "Month": "January", "Pay Period Begin": "01/01/2023", "Pay Period End": "01/31/2023", "Check Date": "01/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 176,
        "Gross Pay": 12477.67, "Net Pay": 8089.59,
        "401K BT": 374.34, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 374.34, "Optional Life": 67.20, "United Way": 50.00,
        "Before Tax Deductions": 1282.00, "After Tax Deductions": 491.54,
        "OASDI Tax": 719.66, "Medicare Tax": 168.31, "Federal Tax": 1181.36, "State Tax": 545.21,
        "Taxes": 2614.54,
        "Regular Pay": 12477.67, "STIP": 0.0, "Vacation": 0.0, "Recognition Award": 0.0
    },
    {
        "Month": "February", "Pay Period Begin": "02/01/2023", "Pay Period End": "02/28/2023", "Check Date": "02/24/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 160,
        "Gross Pay": 12477.67, "Net Pay": 8089.59,
        "401K BT": 374.34, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 374.34, "Optional Life": 67.20, "United Way": 50.00,
        "Before Tax Deductions": 1282.00, "After Tax Deductions": 491.54,
        "OASDI Tax": 719.66, "Medicare Tax": 168.31, "Federal Tax": 1181.36, "State Tax": 545.21,
        "Taxes": 2614.54,
        "Regular Pay": 12477.67, "STIP": 0.0, "Vacation": 0.0, "Recognition Award": 0.0
    },
    {
        "Month": "March (STIP)", "Pay Period Begin": "03/14/2023", "Pay Period End": "03/14/2023", "Check Date": "03/14/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 0,
        "Gross Pay": 37118.64, "Net Pay": 16683.34,
        "401K BT": 10393.22, "Medical FSA": 0.0, "Health Premium": 0.0, "HSA EE": 0.0,
        "401K Roth": 0.0, "Optional Life": 0.0, "United Way": 0.0,
        "Before Tax Deductions": 10393.22, "After Tax Deductions": 0.0,
        "OASDI Tax": 2301.36, "Medicare Tax": 538.22, "Federal Tax": 5879.59, "State Tax": 1322.91,
        "Taxes": 10042.08,
        "Regular Pay": 0.0, "STIP": 37118.64, "Vacation": 0.0, "Recognition Award": 0.0
    },
    {
        "Month": "March", "Pay Period Begin": "03/01/2023", "Pay Period End": "03/31/2023", "Check Date": "03/24/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 184,
        "Gross Pay": 12477.67, "Net Pay": 8089.60,
        "401K BT": 374.34, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 374.34, "Optional Life": 67.20, "United Way": 50.00,
        "Before Tax Deductions": 1282.00, "After Tax Deductions": 491.54,
        "OASDI Tax": 719.66, "Medicare Tax": 168.30, "Federal Tax": 1181.36, "State Tax": 545.21,
        "Taxes": 2614.53,
        "Regular Pay": 12477.67, "STIP": 0.0, "Vacation": 0.0, "Recognition Award": 0.0
    }
]

data += [
    {
        "Month": "April", "Pay Period Begin": "04/01/2023", "Pay Period End": "04/30/2023", "Check Date": "04/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 152,
        "Gross Pay": 13163.95, "Net Pay": 8502.80,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 67.20, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 512.12,
        "OASDI Tax": 762.21, "Medicare Tax": 178.26, "Federal Tax": 1327.82, "State Tax": 578.16,
        "Taxes": 2846.45,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    },
    {
        "Month": "May", "Pay Period Begin": "05/01/2023", "Pay Period End": "05/31/2023", "Check Date": "05/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 176,
        "Gross Pay": 13163.95, "Net Pay": 8498.03,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.36, "Medicare Tax": 178.30, "Federal Tax": 1328.36, "State Tax": 578.28,
        "Taxes": 2847.30,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    },
    {
        "Month": "June", "Pay Period Begin": "06/01/2023", "Pay Period End": "06/30/2023", "Check Date": "06/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 168,
        "Gross Pay": 13163.94, "Net Pay": 8498.03,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.36, "Medicare Tax": 178.29, "Federal Tax": 1328.36, "State Tax": 578.28,
        "Taxes": 2847.29,
        "Regular Pay": 11948.81, "STIP": 0.0, "Vacation": 1215.14, "Recognition Award": 0.0
    }
]

data += [
    {
        "Month": "July", "Pay Period Begin": "07/01/2023", "Pay Period End": "07/31/2023", "Check Date": "07/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 160,
        "Gross Pay": 13163.95, "Net Pay": 8497.19,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.37, "Medicare Tax": 178.30, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.14,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    },
    {
        "Month": "August", "Pay Period Begin": "08/01/2023", "Pay Period End": "08/31/2023", "Check Date": "08/25/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 184,
        "Gross Pay": 13163.94, "Net Pay": 8497.20,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.36, "Medicare Tax": 178.29, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.12,
        "Regular Pay": 13163.94, "STIP": 0.0, "Vacation": 0.0, "Recognition Award": 0.0
    },
    {
        "Month": "September", "Pay Period Begin": "09/01/2023", "Pay Period End": "09/30/2023", "Check Date": "09/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 148,
        "Gross Pay": 13163.96, "Net Pay": 8497.20,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.18,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.60, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.36, "Medicare Tax": 178.29, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.12,
        "Regular Pay": 12860.16, "STIP": 0.0, "Vacation": 1518.93, "Recognition Award": 0.0
    }
]

data += [
    {
        "Month": "October", "Pay Period Begin": "10/01/2023", "Pay Period End": "10/31/2023", "Check Date": "10/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 176,
        "Gross Pay": 13163.95, "Net Pay": 8497.19,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.37, "Medicare Tax": 178.30, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.14,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    },
    {
        "Month": "November", "Pay Period Begin": "11/01/2023", "Pay Period End": "11/30/2023", "Check Date": "11/24/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 160,
        "Gross Pay": 13163.95, "Net Pay": 8497.19,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.37, "Medicare Tax": 178.30, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.14,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    },
    {
        "Month": "December", "Pay Period Begin": "12/01/2023", "Pay Period End": "12/31/2023", "Check Date": "12/26/2023",
        "Employee Name": "Jonathan Oxborrow", "Employee ID": "0377765", "Employer Name": "Caterpillar Inc.",
        "Employer Address": "5205 N O'Connor Boulevard, Suite 100 Irving, TX 75039", "Hours Worked": 168,
        "Gross Pay": 13163.95, "Net Pay": 8497.19,
        "401K BT": 394.92, "Medical FSA": 237.50, "Health Premium": 116.00, "HSA EE": 554.16,
        "401K Roth": 394.92, "Optional Life": 71.12, "United Way": 50.00,
        "Before Tax Deductions": 1302.58, "After Tax Deductions": 516.04,
        "OASDI Tax": 762.37, "Medicare Tax": 178.30, "Federal Tax": 1328.36, "State Tax": 579.11,
        "Taxes": 2848.14,
        "Regular Pay": 12556.38, "STIP": 0.0, "Vacation": 607.57, "Recognition Award": 0.0
    }
]

df = pl.DataFrame(data)

df.glimpse()
# Out:
# Rows: 13
# Columns: 29
# $ Month                 <str> 'January', 'February', 'March (STIP)', 'March', 'April', 'May', 'June', 'July', 'August', 'September'
# $ Pay Period Begin      <str> '01/01/2023', '02/01/2023', '03/14/2023', '03/01/2023', '04/01/2023', '05/01/2023', '06/01/2023', '07/01/2023', '08/01/2023', '09/01/2023'
# $ Pay Period End        <str> '01/31/2023', '02/28/2023', '03/14/2023', '03/31/2023', '04/30/2023', '05/31/2023', '06/30/2023', '07/31/2023', '08/31/2023', '09/30/2023'
# $ Check Date            <str> '01/26/2023', '02/24/2023', '03/14/2023', '03/24/2023', '04/26/2023', '05/26/2023', '06/26/2023', '07/26/2023', '08/25/2023', '09/26/2023'
# $ Employee Name         <str> 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow', 'Jonathan Oxborrow'
# ...

# %%
from fastapi import FastAPI
from pydantic import BaseModel
from typing import List

app = FastAPI()

class Task(BaseModel):
    id: int
    title: str
    completed: bool

@app.get("/tasks/daily", response_model=List[Task], tags=["Tasks"])
def get_daily_tasks():
    """
    Retrieve the list of daily tasks.
    """
    tasks = [
        Task(id=1, title="Check emails", completed=False),
        Task(id=2, title="Team stand-up meeting", completed=True),
        Task(id=3, title="Write project report", completed=False)
    ]
    return tasks
